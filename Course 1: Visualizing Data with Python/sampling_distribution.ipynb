# %% [markdown]
# # Sampling from a Biased Population
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
mean_uofm = 155
sd_uofm = 5
mean_gym = 185
sd_gym = 5
gymperc = 0.30
totalPopSize = 40000

uofm_students = np.random.normal(mean_uofm, sd_uofm, int(totalPopSize * (1 - gymperc)))
students_at_gym = np.random.normal(mean_gym, sd_gym, int(totalPopSize * gymperc))

population = np.append(uofm_students,students_at_gym)

# %%
plt.figure(figsize=(10,10))

plt.subplot(3,1,1)
sns.distplot(uofm_students)
plt.title("UofM Students Only")
plt.xlim([140,200])

plt.subplot(3,1,2)
sns.distplot(students_at_gym)
plt.title("Gym Goers Only")
plt.xlim([140,200])

plt.subplot(3,1,3)
sns.distplot(population)
plt.title("Full Population of UofM Students")
plt.axvline(x = np.mean(population))
plt.xlim([140,200])
# Out:
# /Users/rajdeep_ch/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rajdeep_ch/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rajdeep_ch/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (140.0, 200.0)

# %% [markdown]
# ### What happens if we sample from the entire population?

# %%
numberSamps = 5000
sampSize = 50

mean_distribution = np.empty(numberSamps)

for i in range(numberSamps):
    random_student = np.random.choice(population, sampSize)
    mean_distribution[i] = np.mean(random_student)

# %%
plt.figure(figsize=(10,8))

plt.subplot(2,1,1)
sns.distplot(population)
plt.title("Full Population of UofM Students")
plt.axvline(x = np.mean(population))
plt.xlim([140,200])

plt.subplot(2,1,2)
sns.distplot(mean_distribution)
plt.title("Sampling Distribution of Mean Weight of Gym Goers")
plt.axvline(x = np.mean(population))
plt.axvline(x = np.mean(mean_distribution), color = 'black')
plt.xlim([140,200])
# Out:
# /Users/rajdeep_ch/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rajdeep_ch/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (140.0, 200.0)

# %% [markdown]
# ### What happens if we take a Non-Representative Sample?

# %%
numberSamps = 5000
sampSize = 50


mean_distribution = np.empty(numberSamps)

for i in range(numberSamps):
    random_student = np.random.choice(students_at_gym, sampSize)
    mean_distribution[i] = np.mean(random_student)

# %%
plt.figure(figsize = (10,8))

plt.subplot(2,1,1)
sns.distplot(population)
plt.title("Full Population of Students")
plt.axvline(x = np.mean(population))
plt.xlim([140,200])

plt.subplot(2,1,2)
sns.distplot(mean_distribution)
plt.title("Sampling Distribution of Mean Weight of Gym Goers")
plt.axvline(x = np.mean(population))
plt.axvline(x = np.mean(students_at_gym), color = 'black')
plt.xlim([140,200])
# Out:
# /Users/rajdeep_ch/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rajdeep_ch/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (140.0, 200.0)
